# %% [markdown]
# ###

# %% [markdown]
# # Topics covered
# 1. What is DSA?
# 2. What is Big-O?
# 3. Why do we need Big-O?
# 4. Common complexities with examples.
# 5. Visual way to understand.
# 6. Key takeaways.
#
# ---
#
# # 🚀 Beginner’s Guide to Big-O Notation
#
# If you’re just starting out with **Data Structures and Algorithms (DSA)**, one of the very first concepts you’ll come across is **Big-O Notation**. It might sound mathematical and scary at first, but don’t worry—by the end of this post, you’ll see it’s just a way to measure how efficient your code is.
#
# ---
#
# ## 🧩 Step 1: What is DSA?
#
# * **Data Structures** are ways to store and organize data (like shelves, cupboards, or folders on your laptop).
# * **Algorithms** are step-by-step instructions to solve a problem (like a recipe for cooking).
#
# When combined, they help us solve problems **faster and smarter**.
#
# Example:
#
# * Suppose you need to find a book in a library.
#
#   * If all books are piled randomly, it’ll take ages to search.
#   * But if books are arranged alphabetically (a data structure), and you follow a method like binary search (an algorithm), you’ll find it much faster.
#
# This is why DSA is all about **efficiency**.
#
# ---
#
# ## 📏 Step 2: What is Big-O Notation?
#
# Big-O Notation is a **mathematical way to describe how the performance of an algorithm grows as the input size grows**.
#
# Instead of saying:
#
# > “My program took 10 seconds on 1 million inputs and 20 seconds on 2 million inputs,”
#
# We say:
#
# > “My algorithm runs in **O(n)** time.”
#
# So Big-O is like a **universal language** for programmers to talk about efficiency—independent of the machine, programming language, or environment.
#
# ---
#
# ## ❓ Step 3: Why Do We Need Big-O?
#
# Imagine two programmers write different code to solve the same problem. Which one is better?
#
# * On your laptop, one might look faster.
# * On my laptop, the other might look faster.
#
# ⏱️ Measuring time in seconds isn’t reliable because:
#
# * Different computers have different speeds.
# * The same code may run slower or faster depending on background processes.
# * For small data, both may look “fast,” but for large data, the difference could be huge.
#
# 👉 Big-O solves this by focusing only on **growth rate**.
# It tells us **how the algorithm scales when input gets very large**.
#
# ---
#
# ## 📊 Step 4: Common Big-O Complexities
#
# Here’s a simple table of the most common complexities, from **best to worst**:
#
# | Big-O          | Name          | Example                                     |
# | -------------- | ------------- | ------------------------------------------- |
# | **O(1)**       | Constant Time | Accessing an array element: `arr[5]`.       |
# | **O(log n)**   | Logarithmic   | Binary search in a sorted list.             |
# | **O(n)**       | Linear        | Looping through all elements once.          |
# | **O(n log n)** | Linearithmic  | Merge Sort, Quick Sort (average case).      |
# | **O(n²)**      | Quadratic     | Nested loops (checking all pairs).          |
# | **O(2ⁿ)**      | Exponential   | Recursive Fibonacci (without optimization). |
# | **O(n!)**      | Factorial     | Brute force Traveling Salesman Problem.     |

# %% [markdown]
# ##

# %%
from IPython.display import Image
Image(filename=r"C:\Users\sudha\Desktop\Courses by Msr\Images\output.png", width=1000, height=800)

# %% [markdown]
# ##

# %% [markdown]
# ---
#
# # 📌 Real-Life Examples of Big-O Complexities
#
# ---
#
# ### 🔹 **O(1) – Constant Time**
#
# 👉 **Always takes the same time, no matter how big the input is.**
#
# 📦 Example:
#
# * Grabbing a specific book from a shelf if you know its exact position.
# * In programming: accessing an array element by index (`arr[5]`).
#
# ---
# No matter how big the array, accessing an element takes **constant time**.

# %%
arr = [5, 10, 15, 20]
print(arr[2])  # Always takes the same time
# Out:
# 15

# %% [markdown]
# ### 🔹 **O(log n) – Logarithmic Time**
#
# 👉 **Work reduces drastically each step (divide and conquer).**
#
# 📦 Example:
#
# * Searching for a word in a **dictionary**: you don’t check page by page, you open near the middle, then half again, etc.
# * In programming: **Binary Search**.
#
#   * For 1,000,000 numbers, only \~20 checks needed!
#
# ---
#
#  Each step cuts the search space in half. For 1 million elements, it takes only \~20 steps!

# %%
def binary_search(arr, target):
    low, high = 0, len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            return True
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
            return False

# %% [markdown]
# ### 🔹 **O(n) – Linear Time**
#
# 👉 **Work grows in direct proportion to input size.**
#
# 📦 Example:
#
# * Checking attendance in a class of `n` students by calling each name once.
# * In programming: **Linear Search** (look through every element until found).
#
# ---
# If the list has `n` items, in the worst case we check all `n`.

# %%
def linear_search(arr, target):
    for num in arr:
        if num == target:
            return True
            return False

# %% [markdown]
# ### 🔹 **O(n log n) – Linearithmic Time**
#
# 👉 **A mix of linear and logarithmic (divide & conquer repeated).**
#
# 📦 Example:
#
# * Sorting a deck of cards using **divide and conquer** (like Merge Sort):
#
#   * Split the deck in half → sort halves → merge → repeat.
# * In programming: Merge Sort, Quick Sort (average case).
#
# 💡 How to tell **O(log n)** vs **O(n log n)?**
#
# * If you just **divide repeatedly** (like searching), it’s **log n**.
# * If you **divide repeatedly for every element** (like sorting), it’s **n log n**.
#
# ---

# %% [markdown]
# ### 🔹 **O(n²) – Quadratic Time**
#
# 👉 **Nested loops: comparing every element with every other.**
#
# 📦 Example:
#
# * Checking if any two students in a class know each other → every student shakes hands with every other student.
# * In programming: Bubble Sort, Selection Sort, or checking all pairs.
#
# ---
#
#    ```python
#    for i in range(n):
#        for j in range(n):
#            print(i, j)  # n * n operations
#    ```
#
# Nested loops mean work grows much faster.

# %%
for i in range(5):
    for j in range(5):
        print(i, j)  # n * n operations
# Out:
# 0 0
# 0 1
# 0 2
# 0 3
# 0 4
# 1 0
# 1 1
# 1 2
# 1 3
# 1 4
# 2 0
# 2 1
# 2 2
# 2 3
# 2 4
# 3 0
# 3 1
# 3 2
# 3 3
# 3 4
# 4 0
# 4 1
# 4 2
# 4 3
# 4 4

# %% [markdown]
# Imagine input size `n = 10, 100, 1000`:
#
# * **O(1):** Always \~1 step.
# * **O(log n):** 3 → 7 → 10 steps.
# * **O(n):** 10 → 100 → 1000 steps.
# * **O(n²):** 100 → 10,000 → 1,000,000 steps.
# * **O(2ⁿ):** 1024 → too big for 100! 🚀
#
# So, as `n` grows, the difference between algorithms becomes **huge**.

# %% [markdown]
# ### 🔹 **O(2ⁿ) – Exponential Time**
#
# 👉 **Doubles with each new input. Grows very fast.**
#
# 📦 Example:
#
# * Trying every possible combination of outfits with `n` shirts → 2ⁿ combinations.
# * In programming: Recursive Fibonacci without memoization.
#
# ---

# %% [markdown]
# ### 🔹 **O(n!) – Factorial Time**
#
# 👉 **Try all possible orders.**
#
# 📦 Example:
#
# * Finding the shortest route to visit `n` cities by checking **every possible order** (Traveling Salesman Problem).
# * In programming: Brute force permutations.
#
# ---
#
# # ✅ Quick Recap
#
# * **O(1):** Instant access (grabbing one thing).
# * **O(log n):** Cut the problem in half repeatedly (dictionary search).
# * **O(n):** Go through everything once (roll call).
# * **O(n log n):** Sort using divide-and-conquer (sorting cards).
# * **O(n²):** Compare everything with everything (everyone shakes hands).
# * **O(2ⁿ):** Every choice doubles possibilities (outfit combos).
# * **O(n!):** Try every order (city tour).
#
# ---
#
# 👉 Now, you’ll never confuse **log n vs n log n** —
#
# * **log n:** Divide repeatedly (search).
# * **n log n:** Divide repeatedly **for each element** (sorting).
#
# ---

# %% [markdown]
# ## 📝Key Takeaways
#
# * **Big-O Notation** describes how an algorithm’s time or space grows with input size.
# * It helps us compare algorithms without worrying about machine speed.
# * We ignore constants and focus on the **dominant term**.
# * From best to worst:
#   `O(1) < O(log n) < O(n) < O(n log n) < O(n²) < O(2ⁿ) < O(n!)`.
#
# ---
#
# ✅ That’s your complete beginner-friendly **overview of Big-O Notation**.
# Next in your DSA journey: **Recursion vs Iteration** – two different ways to write algorithms (and their impact on Big-O).
#
# ---

# %% [markdown]
# ##
